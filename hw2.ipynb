# %% [markdown]
# <a href="https://colab.research.google.com/github/nedahosseini/HW/blob/hw2/hw2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import time
import matplotlib.pyplot as plt

def generate_array(length):
  array = [random.randint(1,1000) for i in range(length)]
  return array

def max(lst):
    x = lst[0]
    for i in range(1,len(lst)):
     if lst[i]>x:
         x = lst[i]
    return x

array_length = [10,100,1000,100000,1000000]
array_time = []
for i in array_length:
  array = generate_array(i)
  start = time.time()
  max(array)
  end = time.time()
  execution_time = end-start
  array_time.append(execution_time)


plt.plot(array_length,array_time)
plt.title('time takenby program for different inputsizes')
# Out:
# Text(0.5, 1.0, 'time takenby program for different inputsizes')
